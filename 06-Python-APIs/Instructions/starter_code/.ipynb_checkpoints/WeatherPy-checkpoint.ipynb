# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\dell\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\dell\anaconda3\lib\site-packages (from citipy) (0.16)
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from datetime import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy



# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities)
# Out:
# 607
# ['taoudenni', 'mataura', 'aktyubinskiy', 'butaritari', 'new norfolk', 'cherskiy', 'mar del plata', 'albany', 'taolanaro', 'punta arenas', 'guerrero negro', 'busselton', 'bluff', 'greensburg', 'barrafranca', 'mayskiy', 'sadove', 'yefimovskiy', 'mareeba', 'vaini', 'nanortalik', 'buariki', 'port-cartier', 'xinyu', 'ancud', 'kenora', 'avarua', 'lianzhou', 'hilo', 'port alfred', 'port hedland', 'grand river south east', 'provideniya', 'dikson', 'kavieng', 'anchorage', 'umred', 'rafai', 'portland', 'nizhneyansk', 'phalaborwa', 'vryburg', 'nemuro', 'malabo', 'palabuhanratu', 'thompson', 'east london', 'vicosa do ceara', 'hobart', 'hermanus', 'saryshagan', 'fort morgan', 'sao joao da barra', 'saint-philippe', 'jamestown', 'puerto ayora', 'nikolskoye', 'clyde river', 'padang', 'vila do maio', 'victoria', 'caravelas', 'barbar', 'nishihara', 'fuerte olimpo', 'mahebourg', 'qaanaaq', 'aksu', 'christchurch', 'petropavlovsk-kamchatskiy', 'olafsvik', 'ushuaia', 'pak phanang', 'klaksvik', 'barrow', 'rawson', 'katsuura', 'nome', 'elat', 'sao jose da coroa grande', 'chokurdakh', 'banda aceh', 'we', 'husavik', 'voh', 'harnosand', 'carnarvon', 'ponta delgada', 'makakilo city', 'arraial do cabo', 'ribeira grande', 'karakendzha', 'margate', 'bengkulu', 'tabou', 'kankaanpaa', 'leningradskiy', 'mindelo', 'sibu', 'tiznit', 'jeffersontown', 'kavaratti', 'illoqqortoormiut', 'castro', 'isiro', 'stanovoye', 'vaitupu', 'saint anthony', 'khatanga', 'cidreira', 'pemberton', 'kodiak', 'atuona', 'kapaa', 'burica', 'lebu', 'san rafael del sur', 'mayo', 'juli', 'upernavik', 'cape town', 'tasiilaq', 'severo-kurilsk', 'tsumeb', 'sitka', 'qasigiannguit', 'sola', 'tuatapere', 'yellowknife', 'saleaula', 'tiarei', 'preobrazheniye', 'honjo', 'campoverde', 'irtyshskiy', 'bodden town', 'cozumel', 'chuy', 'llata', 'half moon bay', 'milingimbi', 'warqla', 'mamakan', 'airai', 'grindavik', 'los llanos de aridane', 'rikitea', 'pokhara', 'khandyga', 'puro', 'kruisfontein', 'rio grande', 'namibe', 'longyearbyen', 'aykhal', 'maxixe', 'sao filipe', 'tubruq', 'adilabad', 'karibib', 'bosaso', 'amderma', 'bethel', 'hithadhoo', 'cukai', 'batagay-alyta', 'liverpool', 'bambanglipuro', 'coihaique', 'pisco', 'georgetown', 'bilibino', 'la vega', 'synya', 'topolobampo', 'aklavik', 'zhangjiakou', 'zhuhai', 'angoche', 'bredasdorp', 'gazimurskiy zavod', 'cururupu', 'cambridge', 'kathmandu', 'ormond beach', 'saskylakh', 'prince rupert', 'kloulklubed', 'proletarsk', 'karauzyak', 'pevek', 'skibbereen', 'san cristobal', 'menongue', 'werota', 'harwich', 'dakar', 'klokkarvik', 'azimur', 'kaitangata', 'bairiki', 'mufumbwe', 'mount gambier', 'kiunga', 'lufilufi', 'port elizabeth', 'port-gentil', 'nederland', 'mul', 'cabo san lucas', 'papara', 'lata', 'mildura', 'nuevo progreso', 'souillac', 'lisakovsk', 'manta', 'mys shmidta', 'karlskrona', 'tarudant', 'novoselitskoye', 'sena madureira', 'ponta do sol', 'oksfjord', 'maqrin', 'marystown', 'fairbanks', 'lagoa', 'kultuk', 'nouadhibou', 'manggar', 'epe', 'lazaro cardenas', 'kinkala', 'inhambane', 'tazovskiy', 'sentyabrskiy', 'esperance', 'vanimo', 'barentsburg', 'isangel', 'sur', 'mazyr', 'faanui', 'bolshevik', 'alekseyevsk', 'tuktoyaktuk', 'pacific grove', 'port blair', 'gladstone', 'sinnamary', 'naze', 'awjilah', 'byron bay', 'halalo', 'manyana', 'solnechnyy', 'bud', 'acapulco', 'umm lajj', 'tauranga', 'tiksi', 'lac du bonnet', 'maple creek', 'vila franca do campo', 'kismayo', 'halifax', 'trstena', 'suntar', 'araxa', 'shimoda', 'dingle', 'sinkat', 'saint george', 'turukhansk', 'zaysan', 'gubkin', 'satitoa', 'talnakh', 'bathsheba', 'auki', 'mount isa', 'venta', 'beinamar', 'saint-joseph', 'kahului', 'lompoc', 'loukhi', 'costinesti', 'hastings', 'masoko', 'reconquista', 'clarence town', 'tabarqah', 'lavrentiya', 'verkhnyaya inta', 'yarmouth', 'soe', 'dicabisagan', 'ridgecrest', 'shemgang', 'acacias', 'lorengau', 'mastic beach', 'cayenne', 'naryan-mar', 'ilulissat', 'buala', 'george town', 'lucea', 'sakaiminato', 'belyy yar', 'mantua', 'icod de los vinos', ...

# %%
cities_pd=pd.DataFrame(cities, columns=["City"])

# %%
## Perform API Calls


cities_pd["lat"]=""
cities_pd["lon"]=""
cities_pd["Cloudiness"]=""
cities_pd["Country"]=""
cities_pd["Humidity"]=""
cities_pd["Max Temp"]=""
cities_pd["Wind Speed"]=""
cities_pd["Date"]=""

cities_pd.head()
# Out:
#            City lat lon Cloudiness Country Humidity Max Temp Wind Speed Date
# 0     taoudenni
# 1       mataura
# 2  aktyubinskiy
# 3    butaritari
# 4   new norfolk

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = url + "appid=" + api_key + "&q=" 


counter= 0


print('Beginning Data Retrieval ')
print('-------------------------------------')

for index, row in cities_pd.iterrows():
    try:
        city=row["City"]
        response = requests.get(query_url + city).json()
        lat=response['coord']['lat']
        lon=response['coord']['lon']
        cloud=response['clouds']['all']
        country=response['sys']['country']
        humid=response['main']['humidity']
        max_temp=response['main']['temp_max']
        wind=response['wind']['speed']
        date=response['dt']
        
        cities_pd.at[index, "lat"] = lat
        cities_pd.at[index, "lon"] = lon
        cities_pd.at[index, "Cloudiness"] = cloud
        cities_pd.at[index, "Country"] = country
        cities_pd.at[index, "Humidity"] = humid
        cities_pd.at[index, "Max Temp"] = max_temp
        cities_pd.at[index, "Wind Speed"] = wind
        cities_pd.at[index, "Date"] = date
        print("Processing Record "+ str(counter + 1)+ " of " + str(len(cities))+ " | "+ city)
        print(query_url + city)
        counter= counter+1
    except:
        print("City Not Found")
        cities_pd.drop(labels=index,inplace=True)
      
    
        
print("-------------------------------------")
print("Data Retrieval complete")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of 607 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taoudenni
# Processing Record 2 of 607 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mataura
# Processing Record 3 of 607 | aktyubinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aktyubinskiy
# Processing Record 4 of 607 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=butaritari
# Processing Record 5 of 607 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=new norfolk
# Processing Record 6 of 607 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cherskiy
# Processing Record 7 of 607 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar del plata
# Processing Record 8 of 607 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# City Not Found
# Processing Record 9 of 607 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta arenas
# Processing Record 10 of 607 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=guerrero negro
# Processing Record 11 of 607 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# Processing Record 12 of 607 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# Processing Record 13 of 607 | greensburg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=greensburg
# Processing Record 14 of 607 | barrafranca
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrafranca
# Processing Record 15 of 607 | mayskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mayskiy
# Processing Record 16 of 607 | sadove
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sadove
# City Not Found
# Processing Record 17 of 607 | mareeba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mareeba
# Processing Record 18 of 607 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# Processing Record 19 of 607 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanortalik
# City Not Found
# Processing Record 20 of 607 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port-cartier
# Processing Record 21 of 607 | xinyu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=xinyu
# Processing Record 22 of 607 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ancud
# Processing Record 23 of 607 | kenora
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kenora
# Processing Record 24 of 607 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# Processing Record 25 of 607 | lianzhou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lianzhou
# Processing Record 26 of 607 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# Processing Record 27 of 607 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port alfred
# Processing Record 28 of 607 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port hedland
# City Not Found
# Processing Record 29 of 607 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=provideniya
# Processing Record 30 of 607 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dikson
# Processing Record 31 of 607 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavieng
# Processing Record 32 of 607 | anchorage
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anchorage
# Processing Record 33 of 607 | umred
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=umred
# Processing Record 34 of 607 | rafai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rafai
# Processing Record 35 of 607 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=portland
# City Not Found
# Processing Record 36 of 607 | phalaborwa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=phalaborwa
# Processing Record 37 of 607 | vryburg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vryburg
# Processing Record 38 of 607 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nemuro
# Processing Record 39 of 607 | malabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=malabo
# City Not Found
# Processing Record 40 of 607 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=thompson
# Processing Record 41 of 607 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=east london
# Processing Record 42 of 607 | vicosa do ceara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vicosa do ceara
# Processing Record 43 of 607 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# Processing Record 44 of 607 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hermanus
# City Not Found
# Processing Record 45 of 607 | fort morgan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fort morgan
# Processing Record 46 of 607 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao joao da barra
# Processing Record 47 of 607 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# Processing Record 48 of 607 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# Processing Record 49 of 607 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto ayora
# Processing Record 50 of 607 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nikolskoye
# Processing Record 51 of 607 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde river
# Processing Record 52 of 607 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=padang
# Processing Record 53 of 607 | vila do maio
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila do maio
# Processing Record 54 of 607 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# Processing Record 55 of 607 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=caravelas
# City Not Found
# Processing Record 56 of 607 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nishihara
# Processing Record 57 of 607 | fuerte olimpo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fuerte olimpo
# Processing Record 58 of 607 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# Processing Record 59 of 607 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# Processing Record 60 of 607 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aksu
# Processing Record 61 of 607 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=christchurch
# Processing Record 62 of 607 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=petropavlovsk-kamchatskiy
# City Not Found
# Processing Record 63 of 607 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# Processing Record 64 of 607 | pak phanang
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pak phanang
# Processing Record 65 of 607 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=klaksvik
# Processing Record 66 of 607 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# Processing Record 67 of 607 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rawson
# Processing Record 68 of 607 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# Processing Record 69 of 607 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nome
# Processing Record 70 of 607 | elat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=elat
# Processing Record 71 of 607 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao jose da coroa grande
# Processing Record 72 of 607 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chokurdakh
# Processing Record 73 of 607 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=banda aceh
# City Not Found
# Processing Record 74 of 607 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=husavik
# Processing Record 75 of 607 | voh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=voh
# Processing Record 76 of 607 | harnosand
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=harnosand
# Processing Record 77 of 607 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# Processing Record 78 of 607 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta delgada
# Processing Record 79 of 607 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=makakilo city
# Processing Record 80 of 607 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=arraial do cabo
# Processing Record 81 of 607 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ribeira grande
# City Not Found
# Processing Record 82 of 607 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=margate
# City Not Found
# Processing Record 83 of 607 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tabou
# Processing Record 84 of 607 | kankaanpaa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kankaanpaa
# Processing Record 85 of 607 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=leningradskiy
# Processing Record 86 of 607 | mindelo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mindelo
# Processing Record 87 of 607 | sibu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sibu
# Processing Record 88 of 607 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiznit
# Processing Record 89 of 607 | jeffersontown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jeffersontown
# Processing Record 90 of 607 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavaratti
# City Not Found
# Processing Record 91 of 607 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=castro
# Processing Record 92 of 607 | isiro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=isiro
# Processing Record 93 of 607 | stanovoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=stanovoye
# City Not Found
# Processing Record 94 of 607 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint anthony
# Processing Record 95 of 607 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# Processing Record 96 of 607 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cidreira
# Processing Record 97 of 607 | pemberton
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pemberton
# Processing Record 98 of 607 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kodiak
# Processing Record 99 of 607 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# Processing Record 100 of 607 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# City Not Found
# Processing Record 101 of 607 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebu
# Processing Record 102 of 607 | san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san rafael del sur
# Processing Record 103 of 607 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mayo
# Processing Record 104 of 607 | juli
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=juli
# Processing Record 105 of 607 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=upernavik
# Processing Record 106 of 607 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape town
# Processing Record 107 of 607 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tasiilaq
# Processing Record 108 of 607 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=severo-kurilsk
# Processing Record 109 of 607 | tsumeb
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsumeb
# Processing Record 110 of 607 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sitka
# Processing Record 111 of 607 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qasigiannguit
# Processing Record 112 of 607 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sola
# Processing Record 113 of 607 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuatapere
# Processing Record 114 of 607 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# City Not Found
# Processing Record 115 of 607 | tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiarei
# Processing Record 116 of 607 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=preobrazheniye
# Processing Record 117 of 607 | honjo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=honjo
# Processing Record 118 of 607 | campoverde
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=campoverde
# Processing Record 119 of 607 | irtyshskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=irtyshskiy
# Processing Record 120 of 607 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bodden town
# City Not Found
# Processing Record 121 of 607 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chuy
# Processing Record 122 of 607 | llata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=llata
# Processing Record 123 of 607 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=half moon bay
# City Not Found
# City Not Found
# Processing Record 124 of 607 | mamakan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mamakan
# Processing Record 125 of 607 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# Processing Record 126 of 607 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=grindavik
# Processing Record 127 of 607 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=los llanos de aridane
# Processing Record 128 of 607 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# Processing Record 129 of 607 | pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pokhara
# Processing Record 130 of 607 | khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khandyga
# Processing Record 131 of 607 | puro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puro
# Processing Record 132 of 607 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# Processing Record 133 of 607 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rio grande
# Processing Record 134 of 607 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=namibe
# Processing Record 135 of 607 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=longyearbyen
# Processing Record 136 of 607 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aykhal
# Processing Record 137 of 607 | maxixe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=maxixe
# Processing Record 138 of 607 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao filipe
# City Not Found
# Processing Record 139 of 607 | adilabad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=adilabad
# Processing Record 140 of 607 | karibib
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=karibib
# Processing Record 141 of 607 | bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bosaso
# City Not Found
# Processing Record 142 of 607 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bethel
# Processing Record 143 of 607 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hithadhoo
# Processing Record 144 of 607 | cukai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cukai
# Processing Record 145 of 607 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=batagay-alyta
# Processing Record 146 of 607 | liverpool
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=liverpool
# Processing Record 147 of 607 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bambanglipuro
# Processing Record 148 of 607 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coihaique
# Processing Record 149 of 607 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# Processing Record 150 of 607 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=georgetown
# Processing Record 151 of 607 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bilibino
# Processing Record 152 of 607 | la vega
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=la vega
# Processing Record 153 of 607 | synya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=synya
# Processing Record 154 of 607 | topolobampo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=topolobampo
# Processing Record 155 of 607 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aklavik
# Processing Record 156 of 607 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhangjiakou
# Processing Record 157 of 607 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhuhai
# Processing Record 158 of 607 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=angoche
# Processing Record 159 of 607 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bredasdorp
# Processing Record 160 of 607 | gazimurskiy zavod
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gazimurskiy zavod
# Processing Record 161 of 607 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cururupu
# Processing Record 162 of 607 | cambridge
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cambridge
# Processing Record 163 of 607 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kathmandu
# Processing Record 164 of 607 | ormond beach
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ormond beach
# Processing Record 165 of 607 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# Processing Record 166 of 607 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=prince rupert
# Processing Record 167 of 607 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kloulklubed
# Processing Record 168 of 607 | proletarsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=proletarsk
# City Not Found
# Processing Record 169 of 607 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pevek
# Processing Record 170 of 607 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=skibbereen
# Processing Record 171 of 607 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san cristobal
# Processing Record 172 of 607 | menongue
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=menongue
# Processing Record 173 of 607 | werota
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=werota
# Processing Record 174 of 607 | harwich
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=harwich
# Processing Record 175 of 607 | dakar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dakar
# City Not Found
# City Not Found
# Processing Record 176 of 607 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitangata
# City Not Found
# Processing Record 177 of 607 | mufumbwe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mufumbwe
# Processing Record 178 of 607 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount gambier
# Processing Record 179 of 607 | kiunga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kiunga
# Processing Record 180 of 607 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lufilufi
# Processing Record 181 of 607 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port elizabeth
# Processing Record 182 of 607 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port-gentil
# Processing Record 183 of 607 | nederland
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nederland
# Processing Record 184 of 607 | mul
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mul
# Processing Record 185 of 607 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cabo san lucas
# Processing Record 186 of 607 | papara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=papara
# Processing Record 187 of 607 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lata
# Processing Record 188 of 607 | mildura
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mildura
# Processing Record 189 of 607 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuevo progreso
# Processing Record 190 of 607 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=souillac
# Processing Record 191 of 607 | lisakovsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lisakovsk
# Processing Record 192 of 607 | manta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manta
# City Not Found
# Processing Record 193 of 607 | karlskrona
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=karlskrona
# City Not Found
# Processing Record 194 of 607 | novoselitskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=novoselitskoye
# Processing Record 195 of 607 | sena madureira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sena madureira
# Processing Record 196 of 607 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta do sol
# Processing Record 197 of 607 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=oksfjord
# City Not Found
# Processing Record 198 of 607 | marystown
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=marystown
# Processing Record 199 of 607 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fairbanks
# Processing Record 200 of 607 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lagoa
# Processing Record 201 of 607 | kultuk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kultuk
# Processing Record 202 of 607 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nouadhibou
# Processing Record 203 of 607 | manggar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manggar
# Processing Record 204 of 607 | epe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=epe
# Processing Record 205 of 607 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lazaro cardenas
# Processing Record 206 of 607 | kinkala
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kinkala
# Processing Record 207 of 607 | inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=inhambane
# Processing Record 208 of 607 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tazovskiy
# City Not Found
# Processing Record 209 of 607 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=esperance
# Processing Record 210 of 607 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vanimo
# City Not Found
# Processing Record 211 of 607 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=isangel
# Processing Record 212 of 607 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sur
# Processing Record 213 of 607 | mazyr
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mazyr
# Processing Record 214 of 607 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=faanui
# Processing Record 215 of 607 | bolshevik
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bolshevik
# Processing Record 216 of 607 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alekseyevsk
# Processing Record 217 of 607 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# Processing Record 218 of 607 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pacific grove
# Processing Record 219 of 607 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port blair
# Processing Record 220 of 607 | gladstone
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gladstone
# Processing Record 221 of 607 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sinnamary
# Processing Record 222 of 607 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=naze
# Processing Record 223 of 607 | awjilah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=awjilah
# Processing Record 224 of 607 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=byron bay
# City Not Found
# Processing Record 225 of 607 | manyana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manyana
# Processing Record 226 of 607 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=solnechnyy
# Processing Record 227 of 607 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bud
# Processing Record 228 of 607 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=acapulco
# Processing Record 229 of 607 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=umm lajj
# Processing Record 230 of 607 | tauranga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tauranga
# Processing Record 231 of 607 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# Processing Record 232 of 607 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lac du bonnet
# Processing Record 233 of 607 | maple creek
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=maple creek
# Processing Record 234 of 607 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila franca do campo
# City Not Found
# Processing Record 235 of 607 | halifax
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=halifax
# Processing Record 236 of 607 | trstena
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=trstena
# Processing Record 237 of 607 | suntar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=suntar
# Processing Record 238 of 607 | araxa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=araxa
# Processing Record 239 of 607 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=shimoda
# Processing Record 240 of 607 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dingle
# City Not Found
# Processing Record 241 of 607 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint george
# Processing Record 242 of 607 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=turukhansk
# Processing Record 243 of 607 | zaysan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zaysan
# Processing Record 244 of 607 | gubkin
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gubkin
# City Not Found
# Processing Record 245 of 607 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=talnakh
# Processing Record 246 of 607 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bathsheba
# Processing Record 247 of 607 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=auki
# Processing Record 248 of 607 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount isa
# Processing Record 249 of 607 | venta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=venta
# Processing Record 250 of 607 | beinamar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=beinamar
# Processing Record 251 of 607 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-joseph
# Processing Record 252 of 607 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kahului
# Processing Record 253 of 607 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lompoc
# Processing Record 254 of 607 | loukhi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=loukhi
# Processing Record 255 of 607 | costinesti
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=costinesti
# Processing Record 256 of 607 | hastings
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hastings
# Processing Record 257 of 607 | masoko
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=masoko
# Processing Record 258 of 607 | reconquista
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=reconquista
# Processing Record 259 of 607 | clarence town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clarence town
# City Not Found
# Processing Record 260 of 607 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lavrentiya
# Processing Record 261 of 607 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=verkhnyaya inta
# Processing Record 262 of 607 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yarmouth
# Processing Record 263 of 607 | soe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=soe
# Processing Record 264 of 607 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dicabisagan
# Processing Record 265 of 607 | ridgecrest
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ridgecrest
# Processing Record 266 of 607 | shemgang
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=shemgang
# Processing Record 267 of 607 | acacias
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=acacias
# Processing Record 268 of 607 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lorengau
# Processing Record 269 of 607 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mastic beach
# Processing Record 270 of 607 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cayenne
# Processing Record 271 of 607 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=naryan-mar
# Processing Record 272 of 607 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilulissat
# Processing Record 273 of 607 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=buala
# Processing Record 274 of 607 | george town
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=george town
# Processing Record 275 of 607 | lucea
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lucea
# Processing Record 276 of 607 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sakaiminato
# Processing Record 277 of 607 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=belyy yar
# Processing Record 278 of 607 | mantua
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mantua
# Processing Record 279 of 607 | icod de los vinos
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=icod de los vinos
# Processing Record 280 of 607 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hirara
# Processing Record 281 of 607 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=paita
# Processing Record 282 of 607 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vardo
# Processing Record 283 of 607 | sambava
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sambava
# Processing Record 284 of 607 | lenoir city
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lenoir city
# Processing Record 285 of 607 | buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=buchanan
# Processing Record 286 of 607 | dalmatovo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dalmatovo
# Processing Record 287 of 607 | tagusao
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tagusao
# City Not Found
# Processing Record 288 of 607 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=seoul
# Processing Record 289 of 607 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=viedma
# Processing Record 290 of 607 | elko
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=elko
# Processing Record 291 of 607 | moron
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=moron
# City Not Found
# Processing Record 292 of 607 | buta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=buta
# Processing Record 293 of 607 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=antofagasta
# Processing Record 294 of 607 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman wells
# Processing Record 295 of 607 | concarneau
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=concarneau
# Processing Record 296 of 607 | hulan ergi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hulan ergi
# Processing Record 297 of 607 | anloga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anloga
# Processing Record 298 of 607 | jackson
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jackson
# Processing Record 299 of 607 | palembang
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=palembang
# Processing Record 300 of 607 | grand-lahou
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand-lahou
# City Not Found
# Processing Record 301 of 607 | rochegda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rochegda
# Processing Record 302 of 607 | carballo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carballo
# Processing Record 303 of 607 | vavuniya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vavuniya
# City Not Found
# Processing Record 304 of 607 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fortuna
# Processing Record 305 of 607 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kutum
# Processing Record 306 of 607 | carnot
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnot
# Processing Record 307 of 607 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bonavista
# Processing Record 308 of 607 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=arman
# Processing Record 309 of 607 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto escondido
# Processing Record 310 of 607 | mvuma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mvuma
# Processing Record 311 of 607 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samarai
# City Not Found
# Processing Record 312 of 607 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sioux lookout
# Processing Record 313 of 607 | pucara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pucara
# Processing Record 314 of 607 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=touros
# Processing Record 315 of 607 | ayan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ayan
# Processing Record 316 of 607 | nur
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nur
# Processing Record 317 of 607 | awbari
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=awbari
# Processing Record 318 of 607 | bang saphan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bang saphan
# Processing Record 319 of 607 | urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=urengoy
# Processing Record 320 of 607 | holme
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=holme
# Processing Record 321 of 607 | sochaczew
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sochaczew
# Processing Record 322 of 607 | trujillo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=trujillo
# Processing Record 323 of 607 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dawlatabad
# Processing Record 324 of 607 | ocampo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ocampo
# Processing Record 325 of 607 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambilobe
# Processing Record 326 of 607 | pahrump
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pahrump
# Processing Record 327 of 607 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=oktyabrskoye
# Processing Record 328 of 607 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pangnirtung
# Processing Record 329 of 607 | vila
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila
# City Not Found
# Processing Record 330 of 607 | sarangani
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sarangani
# City Not Found
# Processing Record 331 of 607 | clevelandia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clevelandia
# Processing Record 332 of 607 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=te anau
# Processing Record 333 of 607 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila velha
# Processing Record 334 of 607 | roma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=roma
# Processing Record 335 of 607 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=salalah
# Processing Record 336 of 607 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=baykit
# Processing Record 337 of 607 | lima
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lima
# City Not Found
# Processing Record 338 of 607 | san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san rafael
# Processing Record 339 of 607 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mehamn
# Processing Record 340 of 607 | paragominas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=paragominas
# Processing Record 341 of 607 | agadir
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=agadir
# Processing Record 342 of 607 | zlitan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zlitan
# Processing Record 343 of 607 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=berlevag
# Processing Record 344 of 607 | rocha
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=katherine
# Processing Record 432 of 607 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yeppoon
# Processing Record 433 of 607 | bethanien
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bethanien
# City Not Found
# Processing Record 434 of 607 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao felix do xingu
# Processing Record 435 of 607 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=conde
# City Not Found
# Processing Record 436 of 607 | woodward
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=woodward
# Processing Record 437 of 607 | male
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=male
# Processing Record 438 of 607 | methoni
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=methoni
# Processing Record 439 of 607 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=broome
# Processing Record 440 of 607 | peniche
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=peniche
# Processing Record 441 of 607 | mizdah
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mizdah
# Processing Record 442 of 607 | surgut
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=surgut
# Processing Record 443 of 607 | storsteinnes
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=storsteinnes
# Processing Record 444 of 607 | visnes
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=visnes
# Processing Record 445 of 607 | inta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=inta
# Processing Record 446 of 607 | balabac
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=balabac
# Processing Record 447 of 607 | owerri
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=owerri
# Processing Record 448 of 607 | molochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=molochnoye
# City Not Found
# Processing Record 449 of 607 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=henties bay
# Processing Record 450 of 607 | jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jinchang
# Processing Record 451 of 607 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=maniitsoq
# Processing Record 452 of 607 | pitanga
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pitanga
# Processing Record 453 of 607 | brae
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=brae
# Processing Record 454 of 607 | tulum
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tulum
# Processing Record 455 of 607 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tautira
# Processing Record 456 of 607 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sungaipenuh
# Processing Record 457 of 607 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fukue
# City Not Found
# Processing Record 458 of 607 | port victoria
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port victoria
# Processing Record 459 of 607 | nurota
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nurota
# Processing Record 460 of 607 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bilma
# Processing Record 461 of 607 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=camacha
# Processing Record 462 of 607 | laurel
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=laurel
# Processing Record 463 of 607 | la sarre
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=la sarre
# Processing Record 464 of 607 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kalmunai
# Processing Record 465 of 607 | bowen
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bowen
# Processing Record 466 of 607 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bandarbeyla
# Processing Record 467 of 607 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coahuayana
# Processing Record 468 of 607 | hot springs
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hot springs
# Processing Record 469 of 607 | jiayuguan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiayuguan
# City Not Found
# Processing Record 470 of 607 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coquimbo
# Processing Record 471 of 607 | gamba
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gamba
# Processing Record 472 of 607 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atambua
# City Not Found
# Processing Record 473 of 607 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=santa vitoria do palmar
# Processing Record 474 of 607 | sierra vista
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sierra vista
# Processing Record 475 of 607 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=krasnyy chikoy
# Processing Record 476 of 607 | matay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=matay
# Processing Record 477 of 607 | manassas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manassas
# Processing Record 478 of 607 | atasu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atasu
# Processing Record 479 of 607 | galle
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=galle
# Processing Record 480 of 607 | stanger
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=stanger
# Processing Record 481 of 607 | lebanon
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebanon
# Processing Record 482 of 607 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=elizabeth city
# Processing Record 483 of 607 | kharhial
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kharhial
# Processing Record 484 of 607 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vestmannaeyjar
# Processing Record 485 of 607 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=axim
# Processing Record 486 of 607 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chicama
# Processing Record 487 of 607 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=talcahuano
# Processing Record 488 of 607 | nuevitas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuevitas
# Processing Record 489 of 607 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rovaniemi
# City Not Found
# Processing Record 490 of 607 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alofi
# Processing Record 491 of 607 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhigansk
# Processing Record 492 of 607 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alta floresta
# Processing Record 493 of 607 | quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=quelimane
# Processing Record 494 of 607 | cacoal
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cacoal
# Processing Record 495 of 607 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaqortoq
# Processing Record 496 of 607 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port macquarie
# Processing Record 497 of 607 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bubaque
# Processing Record 498 of 607 | duncan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=duncan
# Processing Record 499 of 607 | balbalan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=balbalan
# Processing Record 500 of 607 | ypsonas
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ypsonas
# Processing Record 501 of 607 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mabaruma
# Processing Record 502 of 607 | kabinda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kabinda
# Processing Record 503 of 607 | irkutsk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=irkutsk
# Processing Record 504 of 607 | dauriya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dauriya
# Processing Record 505 of 607 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=olinda
# Processing Record 506 of 607 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=eydhafushi
# Processing Record 507 of 607 | puerto suarez
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto suarez
# Processing Record 508 of 607 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nhulunbuy
# Processing Record 509 of 607 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=beloha
# Processing Record 510 of 607 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hovd
# Processing Record 511 of 607 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=komsomolskiy
# Processing Record 512 of 607 | loikaw
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=loikaw
# Processing Record 513 of 607 | piterka
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=piterka
# City Not Found
# Processing Record 514 of 607 | corinto
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=corinto
# City Not Found
# Processing Record 515 of 607 | qovlar
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qovlar
# City Not Found
# Processing Record 516 of 607 | aitape
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aitape
# Processing Record 517 of 607 | okrika
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=okrika
# Processing Record 518 of 607 | vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitape
# Processing Record 519 of 607 | chesley
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chesley
# Processing Record 520 of 607 | shangzhi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=shangzhi
# Processing Record 521 of 607 | dubai
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dubai
# Processing Record 522 of 607 | redding
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=redding
# Processing Record 523 of 607 | dabhoi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dabhoi
# Processing Record 524 of 607 | solano
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=solano
# City Not Found
# Processing Record 525 of 607 | sao geraldo do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao geraldo do araguaia
# Processing Record 526 of 607 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=codrington
# Processing Record 527 of 607 | klamath falls
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=klamath falls
# Processing Record 528 of 607 | yarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yarkovo
# Processing Record 529 of 607 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=teya
# Processing Record 530 of 607 | vanavara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vanavara
# Processing Record 531 of 607 | soubre
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=soubre
# Processing Record 532 of 607 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=piacabucu
# City Not Found
# Processing Record 533 of 607 | goruia
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=goruia
# City Not Found
# Processing Record 534 of 607 | ankara
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ankara
# Processing Record 535 of 607 | andros
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=andros
# Processing Record 536 of 607 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=labytnangi
# Processing Record 537 of 607 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=luwuk
# Processing Record 538 of 607 | spring valley
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=spring valley
# Processing Record 539 of 607 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vao
# Processing Record 540 of 607 | abeokuta
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=abeokuta
# Processing Record 541 of 607 | angoram
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=angoram
# Processing Record 542 of 607 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuhan
# Processing Record 543 of 607 | masindi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=masindi
# Processing Record 544 of 607 | malinyi
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=malinyi
# Processing Record 545 of 607 | hare bay
# http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hare bay
# -------------------------------------
# Data Retrieval complete

# %%
cities_pd.head()
# Out:
#            City    lat     lon Cloudiness Country Humidity Max Temp  \
# 0     taoudenni  22.68   -3.98          0      ML        8   315.97
# 1       mataura -46.19  168.86         36      NZ       75   279.32
# 2  aktyubinskiy  54.81   52.81          0      RU       74   290.52
# 3    butaritari   3.07  172.79         32      KI      100   300.97
# 4   new norfolk -42.78  147.06         40      AU       97   280.15
#
#   Wind Speed        Date
# 0       3.56  1530981246
# 1       2.31  1530981246
# 2       1.21  1530981246
# 3       3.81  1530981246
# 4        7.7  1530979260

# %%
cities_pd.count()
# Out:
# City          545
# lat           545
# lon           545
# Cloudiness    545
# Country       545
# Humidity      545
# Max Temp      545
# Wind Speed    545
# Date          545
# dtype: int64

# %%
cities_pd.to_excel("output_data/cities.xlsx", index=False)

# %%
plt.scatter(cities_pd["lat"],cities_pd["Max Temp"])

plt.title(f"Latitude vs.Maximum Temperature on {datetime.now()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.grid()
plt.savefig("../Images/Temperature.png")
plt.show()

# %%
plt.scatter(cities_pd["lat"],cities_pd["Humidity"])

plt.title(f"Latitude vs. Humidity on {datetime.now()}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig("../Images/Humidity.png")
plt.show()

# %%
plt.scatter(cities_pd["lat"],cities_pd["Wind Speed"])

plt.title(f"Latitude vs. Wind Speed on {datetime.now()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig("../Images/Wind Speed.png")
plt.show()

# %%
plt.scatter(cities_pd["lat"],cities_pd["Cloudiness"])

plt.title(f"Latitude vs.Cloudiness on {datetime.now()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig("../Images/Cloudiness.png")
plt.show()
